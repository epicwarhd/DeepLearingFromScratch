# %%
from keras.layers import *
import tensorflow as tf
from keras import backend
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
import datetime
from keras.models import Model

# %% [markdown]
# # **MobileNet_V1**

# %%
def depthwise_separable(my_input, filters_pointwise, kernel, stride):
    x = DepthwiseConv2D(kernel_size=kernel, strides=stride, padding='same')(my_input)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv2D(filters_pointwise, 1)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    return x


def mobile_net_v1(classes):
    my_input = Input((224, 224, 3))
    x = Conv2D(32, 3, 2, padding='same')(my_input)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = depthwise_separable(x, 64, 3, 1)
    x = depthwise_separable(x, 128, 3, 2)
    x = depthwise_separable(x, 128, 3, 1)
    x = depthwise_separable(x, 256, 3, 2)
    x = depthwise_separable(x, 256, 3, 1)
    x = depthwise_separable(x, 512, 3, 2)

    for i in range(5):
      x = depthwise_separable(x, 512, 3, 1)

    x = depthwise_separable(x, 1024, 3, 2)
    x = depthwise_separable(x, 1024, 3, 1)

    x = GlobalAveragePooling2D()(x)
    x = Dense(classes, activation='softmax')(x)

    model = Model(inputs=my_input, outputs=x)

    return model

# %%
model = mobile_net_v1(1000)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 112, 112, 32)      896
#
#  batch_normalization (BatchN  (None, 112, 112, 32)     128
#  ormalization)
#
#  re_lu (ReLU)                (None, 112, 112, 32)      0
#
#  depthwise_conv2d (Depthwise  (None, 112, 112, 32)     320
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 112, 112, 32)     128
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 112, 112, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      2112
#
#  batch_normalization_2 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 112, 112, 64)      0
#
#  depthwise_conv2d_1 (Depthwi  (None, 56, 56, 64)       640
#  seConv2D)
#
#  batch_normalization_3 (Batc  (None, 56, 56, 64)       256
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 56, 56, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       8320
#
#  batch_normalization_4 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 56, 56, 128)       0
#
#  depthwise_conv2d_2 (Depthwi  (None, 56, 56, 128)      1280
#  seConv2D)
#
#  batch_normalization_5 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  re_lu_5 (ReLU)              (None, 56, 56, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 128)       16512
#
#  batch_normalization_6 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  re_lu_6 (ReLU)              (None, 56, 56, 128)       0
#
#  depthwise_conv2d_3 (Depthwi  (None, 28, 28, 128)      1280
#  seConv2D)
#
#  batch_normalization_7 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  re_lu_7 (ReLU)              (None, 28, 28, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 256)       33024
#
#  batch_normalization_8 (Batc  (None, 28, 28, 256)      1024
#  hNormalization)
#
#  re_lu_8 (ReLU)              (None, 28, 28, 256)       0
#
#  depthwise_conv2d_4 (Depthwi  (None, 28, 28, 256)      2560
#  seConv2D)
#
#  batch_normalization_9 (Batc  (None, 28, 28, 256)      1024
#  hNormalization)
#
#  re_lu_9 (ReLU)              (None, 28, 28, 256)       0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 256)       65792
#
#  batch_normalization_10 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  re_lu_10 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_5 (Depthwi  (None, 14, 14, 256)      2560
#  seConv2D)
#
#  batch_normalization_11 (Bat  (None, 14, 14, 256)      1024
#  chNormalization)
#
#  re_lu_11 (ReLU)             (None, 14, 14, 256)       0
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 512)       131584
#
#  batch_normalization_12 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_12 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_6 (Depthwi  (None, 14, 14, 512)      5120
#  seConv2D)
#
#  batch_normalization_13 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_13 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 512)       262656
#
#  batch_normalization_14 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_14 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_7 (Depthwi  (None, 14, 14, 512)      5120
#  seConv2D)
#
#  batch_normalization_15 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_15 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 512)       262656
#
#  batch_normalization_16 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_16 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_8 (Depthwi  (None, 14, 14, 512)      5120
#  seConv2D)
#
#  batch_normalization_17 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_17 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 512)       262656
#
#  batch_normalization_18 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_18 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_9 (Depthwi  (None, 14, 14, 512)      5120
#  seConv2D)
#
#  batch_normalization_19 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_19 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       262656
#
#  batch_normalization_20 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_20 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_10 (Depthw  (None, 14, 14, 512)      5120
#  iseConv2D)
#
#  batch_normalization_21 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_21 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       262656
#
#  batch_normalization_22 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_22 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_11 (Depthw  (None, 7, 7, 512)        5120
#  iseConv2D)
#
#  batch_normalization_23 (Bat  (None, 7, 7, 512)        2048
#  chNormalization)
#
#  re_lu_23 (ReLU)             (None, 7, 7, 512)         0
#
#  conv2d_12 (Conv2D)          (None, 7, 7, 1024)        525312
#
#  batch_normalization_24 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  re_lu_24 (ReLU)             (None, 7, 7, 1024)        0
#
#  depthwise_conv2d_12 (Depthw  (None, 7, 7, 1024)       10240
#  iseConv2D)
#
#  batch_normalization_25 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  re_lu_25 (ReLU)             (None, 7, 7, 1024)        0
#
#  conv2d_13 (Conv2D)          (None, 7, 7, 1024)        1049600
#
#  batch_normalization_26 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  re_lu_26 (ReLU)             (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1000)              1025000
#
# =================================================================
# Total params: 4,264,808
# Trainable params: 4,242,920
# Non-trainable params: 21,888
# _________________________________________________________________

# %% [markdown]
# # **MobileNet_V2**

# %%
def bottle_neck_v2(my_input, t, filters, stride, out_channels):
    x = Conv2D(filters*t, 1, 1)(my_input)
    x = BatchNormalization()(x)
    x = ReLU(6)(x)

    x = DepthwiseConv2D(3, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU(6)(x)

    x = Conv2D(out_channels, 1, 1)(x)
    x = BatchNormalization()(x)

    if my_input.shape[-1] == x.shape[-1]:
      x = Add()([my_input, x])

    return x


def mobilenet_v2(classes):
    my_input = Input(shape=(224, 224, 3))
    x = Conv2D(32, 3, 2, padding='same')(my_input)
    x = BatchNormalization()(x)
    x = ReLU(6)(x)

    x = bottle_neck_v2(x, 1, x.shape[-1], 1, 16)

    x = bottle_neck_v2(x, 6, x.shape[-1], 2, 24)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 24)

    x = bottle_neck_v2(x, 6, x.shape[-1], 2, 32)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 32)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 32)

    x = bottle_neck_v2(x, 6, x.shape[-1], 2, 64)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 64)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 64)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 64)

    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 96)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 96)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 96)

    x = bottle_neck_v2(x, 6, x.shape[-1], 2, 160)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 160)
    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 160)

    x = bottle_neck_v2(x, 6, x.shape[-1], 1, 320)

    x = Conv2D(1280, 1, 1, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU(6)(x)

    x = GlobalAveragePooling2D()(x)
    x = Dense(classes, activation='softmax')(x)

    model = Model(inputs=my_input, outputs=x)

    return model

# %%
model = mobilenet_v2(10)
model.summary()

# %% [markdown]
# # **MobileNet_V3**

# %%
def h_swish(x):
    return (x * tf.nn.relu6(x+3)) / 6


def se_block(x, ch, ratio=16):
    x_copy = x
    x = GlobalAveragePooling2D()(x)
    x = Dense(ch//ratio, activation='relu')(x)
    x = Dense(ch, activation='sigmoid')(x)
    x = Multiply()([x_copy, x])
    return x


def custom_activation(x, name):
    if name == "RE":
        # ReLU6
        x = backend.relu(x, max_value=6)
    else:
        # Hard swish
        x = x * backend.relu(x, max_value=6) / 6

    return x


def bottle_neck_v3(my_input, exp_size, out_channels, se, at, stride, kernel):
    x = Conv2D(exp_size, 1, 1)(my_input)
    x = BatchNormalization()(x)
    x = custom_activation(x, at)

    x = DepthwiseConv2D(kernel_size=kernel, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = custom_activation(x, at)

    if se == True:
      x = se_block(x, x.shape[-1])

    x = Conv2D(out_channels, 1, 1)(x)
    x = BatchNormalization()(x)

    if my_input.shape[-1] == x.shape[-1]:
      x = Add()([my_input, x])

    return x


def mobilenet_v3_large(classes):
    my_input = Input(shape=(224, 224, 3))
    x = Conv2D(16, 3, 2, padding='same')(my_input)
    x = BatchNormalization()(x)
    x = custom_activation(x, "HS")

    x = bottle_neck_v3(x, 16, 16, False, "RE", 1, 3)
    x = bottle_neck_v3(x, 64, 24, False, "RE", 2, 3)
    x = bottle_neck_v3(x, 72, 24, False, "RE", 1, 3)
    x = bottle_neck_v3(x, 72, 40, True, "RE", 2, 5)
    x = bottle_neck_v3(x, 120, 40, True, "RE", 1, 5)
    x = bottle_neck_v3(x, 120, 40, True, "RE", 1, 5)
    x = bottle_neck_v3(x, 240, 80, False, "HS", 2, 3)
    x = bottle_neck_v3(x, 200, 80, False, "HS", 1, 3)
    x = bottle_neck_v3(x, 184, 80, False, "HS", 1, 3)
    x = bottle_neck_v3(x, 184, 80, False, "HS", 1, 3)
    x = bottle_neck_v3(x, 480, 112, True, "HS", 1, 3)
    x = bottle_neck_v3(x, 672, 112, True, "HS", 1, 3)
    x = bottle_neck_v3(x, 672, 160, True, "HS", 2, 5)
    x = bottle_neck_v3(x, 960, 160, True, "HS", 1, 5)
    x = bottle_neck_v3(x, 960, 160, True, "HS", 1, 5)

    x = Conv2D(960, 1, 1, padding='same')(x)
    x = BatchNormalization()(x)
    x = custom_activation(x, "HS")

    x = GlobalAveragePooling2D()(x)
    x = Dense(1280)(x)
    x = BatchNormalization()(x)
    x = custom_activation(x, "HS")

    x = Dense(classes, activation='softmax')(x)

    model = Model(inputs=my_input, outputs=x)

    return model

# %%
model = mobilenet_v3_large(10)
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_207 (Conv2D)            (None, 112, 112, 16  448         ['input_10[0][0]']
#                                 )
#
#  batch_normalization_308 (Batch  (None, 112, 112, 16  64         ['conv2d_207[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu6_113 (TFOpLambda)   (None, 112, 112, 16  0           ['batch_normalization_308[0][0]']
#                                 )
#
#  tf.math.multiply_65 (TFOpLambd  (None, 112, 112, 16  0          ['batch_normalization_308[0][0]',
#  a)                             )                                 'tf.nn.relu6_113[0][0]']
#
#  tf.math.truediv_65 (TFOpLambda  (None, 112, 112, 16  0          ['tf.math.multiply_65[0][0]']
#  )                              )
#
#  conv2d_208 (Conv2D)            (None, 112, 112, 16  272         ['tf.math.truediv_65[0][0]']
#                                 )
#
#  batch_normalization_309 (Batch  (None, 112, 112, 16  64         ['conv2d_208[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu6_114 (TFOpLambda)   (None, 112, 112, 16  0           ['batch_normalization_309[0][0]']
#                                 )
#
#  depthwise_conv2d_96 (Depthwise  (None, 112, 112, 16  160        ['tf.nn.relu6_114[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_310 (Batch  (None, 112, 112, 16  64         ['depthwise_conv2d_96[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu6_115 (TFOpLambda)   (None, 112, 112, 16  0           ['batch_normalization_310[0][0]']
#                                 )
#
#  conv2d_209 (Conv2D)            (None, 112, 112, 16  272         ['tf.nn.relu6_115[0][0]']
#                                 )
#
#  batch_normalization_311 (Batch  (None, 112, 112, 16  64         ['conv2d_209[0][0]']
#  Normalization)                 )
#
#  add_64 (Add)                   (None, 112, 112, 16  0           ['tf.math.truediv_65[0][0]',
#                                 )                                 'batch_normalization_311[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 112, 112, 64  1088        ['add_64[0][0]']
#                                 )
#
#  batch_normalization_312 (Batch  (None, 112, 112, 64  256        ['conv2d_210[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu6_116 (TFOpLambda)   (None, 112, 112, 64  0           ['batch_normalization_312[0][0]']
#                                 )
#
#  depthwise_conv2d_97 (Depthwise  (None, 56, 56, 64)  640         ['tf.nn.relu6_116[0][0]']
#  Conv2D)
#
#  batch_normalization_313 (Batch  (None, 56, 56, 64)  256         ['depthwise_conv2d_97[0][0]']
#  Normalization)
#
#  tf.nn.relu6_117 (TFOpLambda)   (None, 56, 56, 64)   0           ['batch_normalization_313[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 56, 56, 24)   1560        ['tf.nn.relu6_117[0][0]']
#
#  batch_normalization_314 (Batch  (None, 56, 56, 24)  96          ['conv2d_211[0][0]']
#  Normalization)
#
#  conv2d_212 (Conv2D)            (None, 56, 56, 72)   1800        ['batch_normalization_314[0][0]']
#
#  batch_normalization_315 (Batch  (None, 56, 56, 72)  288         ['conv2d_212[0][0]']
#  Normalization)
#
#  tf.nn.relu6_118 (TFOpLambda)   (None, 56, 56, 72)   0           ['batch_normalization_315[0][0]']
#
#  depthwise_conv2d_98 (Depthwise  (None, 56, 56, 72)  720         ['tf.nn.relu6_118[0][0]']
#  Conv2D)
#
#  batch_normalization_316 (Batch  (None, 56, 56, 72)  288         ['depthwise_conv2d_98[0][0]']
#  Normalization)
#
#  tf.nn.relu6_119 (TFOpLambda)   (None, 56, 56, 72)   0           ['batch_normalization_316[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 56, 56, 24)   1752        ['tf.nn.relu6_119[0][0]']
#
#  batch_normalization_317 (Batch  (None, 56, 56, 24)  96          ['conv2d_213[0][0]']
#  Normalization)
#
#  add_65 (Add)                   (None, 56, 56, 24)   0           ['batch_normalization_314[0][0]',
#                                                                   'batch_normalization_317[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 56, 56, 72)   1800        ['add_65[0][0]']
#
#  batch_normalization_318 (Batch  (None, 56, 56, 72)  288         ['conv2d_214[0][0]']
#  Normalization)
#
#  tf.nn.relu6_120 (TFOpLambda)   (None, 56, 56, 72)   0           ['batch_normalization_318[0][0]']
#
#  depthwise_conv2d_99 (Depthwise  (None, 28, 28, 72)  1872        ['tf.nn.relu6_120[0][0]']
#  Conv2D)
#
#  batch_normalization_319 (Batch  (None, 28, 28, 72)  288         ['depthwise_conv2d_99[0][0]']
#  Normalization)
#
#  tf.nn.relu6_121 (TFOpLambda)   (None, 28, 28, 72)   0           ['batch_normalization_319[0][0]']
#
#  global_average_pooling2d_53 (G  (None, 72)          0           ['tf.nn.relu6_121[0][0]']
#  lobalAveragePooling2D)
#
#  dense_109 (Dense)              (None, 4)            292         ['global_average_pooling2d_53[0][
#                                                                  0]']
#
#  dense_110 (Dense)              (None, 72)           360         ['dense_109[0][0]']
#
#  multiply_48 (Multiply)         (None, 28, 28, 72)   0           ['tf.nn.relu6_121[0][0]',
#                                                                   'dense_110[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 28, 28, 40)   2920        ['multiply_48[0][0]']
#
#  batch_normalization_320 (Batch  (None, 28, 28, 40)  160         ['conv2d_215[0][0]']
#  Normalization)
#
#  conv2d_216 (Conv2D)            (None, 28, 28, 120)  4920        ['batch_normalization_320[0][0]']
#
#  batch_normalization_321 (Batch  (None, 28, 28, 120)  480        ['conv2d_216[0][0]']
#  Normalization)
#
#  tf.nn.relu6_122 (TFOpLambda)   (None, 28, 28, 120)  0           ['batch_normalization_321[0][0]']
#
#  depthwise_conv2d_100 (Depthwis  (None, 28, 28, 120)  3120       ['tf.nn.relu6_122[0][0]']
#  eConv2D)
#
#  batch_normalization_322 (Batch  (None, 28, 28, 120)  480        ['depthwise_conv2d_100[0][0]']
#  Normalization)
#
#  tf.nn.relu6_123 (TFOpLambda)   (None, 28, 28, 120)  0           ['batch_normalization_322[0][0]']
#
#  global_average_pooling2d_54 (G  (None, 120)         0           ['tf.nn.relu6_123[0][0]']
#  lobalAveragePooling2D)
#
#  dense_111 (Dense)              (None, 7)            847         ['global_average_pooling2d_54[0][
#                                                                  0]']
#
#  dense_112 (Dense)              (None, 120)          960         ['dense_111[0][0]']
#
#  multiply_49 (Multiply)         (None, 28, 28, 120)  0           ['tf.nn.relu6_123[0][0]',
#                                                                   'dense_112[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 28, 28, 40)   4840        ['multiply_49[0][0]']
#
#  batch_normalization_323 (Batch  (None, 28, 28, 40)  160         ['conv2d_217[0][0]']
#  Normalization)
#
#  add_66 (Add)                   (None, 28, 28, 40)   0           ['batch_normalization_320[0][0]',
#                                                                   'batch_normalization_323[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 28, 28, 120)  4920        ['add_66[0][0]']
#
#  batch_normalization_324 (Batch  (None, 28, 28, 120)  480        ['conv2d_218[0][0]']
#  Normalization)
#
#  tf.nn.relu6_124 (TFOpLambda)   (None, 28, 28, 120)  0           ['batch_normalization_324[0][0]']
#
#  depthwise_conv2d_101 (Depthwis  (None, 28, 28, 120)  3120       ['tf.nn.relu6_124[0][0]']
#  eConv2D)
#
#  batch_normalization_325 (Batch  (None, 28, 28, 120)  480        ['depthwise_conv2d_101[0][0]']
#  Normalization)
#
#  tf.nn.relu6_125 (TFOpLambda)   (None, 28, 28, 120)  0           ['batch_normalization_325[0][0]']
#
#  global_average_pooling2d_55 (G  (None, 120)         0           ['tf.nn.relu6_125[0][0]']
#  lobalAveragePooling2D)
#
#  dense_113 (Dense)              (None, 7)            847         ['global_average_pooling2d_55[0][
#                                                                  0]']
#
#  dense_114 (Dense)              (None, 120)          960         ['dense_113[0][0]']
#
#  multiply_50 (Multiply)         (None, 28, 28, 120)  0           ['tf.nn.relu6_125[0][0]',
#                                                                   'dense_114[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 28, 28, 40)   4840        ['multiply_50[0][0]']
#
#  batch_normalization_326 (Batch  (None, 28, 28, 40)  160         ['conv2d_219[0][0]']
#  Normalization)
#
#  add_67 (Add)                   (None, 28, 28, 40)   0           ['add_66[0][0]',
#                                                                   'batch_normalization_326[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 28, 28, 240)  9840        ['add_67[0][0]']
#
#  batch_normalization_327 (Batch  (None, 28, 28, 240)  960        ['conv2d_220[0][0]']
#  Normalization)
#
#  tf.nn.relu6_126 (TFOpLambda)   (None, 28, 28, 240)  0           ['batch_normalization_327[0][0]']
#
#  tf.math.multiply_66 (TFOpLambd  (None, 28, 28, 240)  0          ['batch_normalization_327[0][0]',
#  a)                                                               'tf.nn.relu6_126[0][0]']
#
#  tf.math.truediv_66 (TFOpLambda  (None, 28, 28, 240)  0          ['tf.math.multiply_66[0][0]']
#  )
#
#  depthwise_conv2d_102 (Depthwis  (None, 14, 14, 240)  2400       ['tf.math.truediv_66[0][0]']
#  eConv2D)
#
#  batch_normalization_328 (Batch  (None, 14, 14, 240)  960        ['depthwise_conv2d_102[0][0]']
#  Normalization)
#
#  tf.nn.relu6_127 (TFOpLambda)   (None, 14, 14, 240)  0           ['batch_normalization_328[0][0]']
#
#  tf.math.multiply_67 (TFOpLambd  (None, 14, 14, 240)  0          ['batch_normalization_328[0][0]',
#  a)                                                               'tf.nn.relu6_127[0][0]']
#
#  tf.math.truediv_67 (TFOpLambda  (None, 14, 14, 240)  0          ['tf.math.multiply_67[0][0]']
#  )
#
#  conv2d_221 (Conv2D)            (None, 14, 14, 80)   19280       ['tf.math.truediv_67[0][0]']
#
#  batch_normalization_329 (Batch  (None, 14, 14, 80)  320         ['conv2d_221[0][0]']
#  Normalization)
#
#  conv2d_222 (Conv2D)            (None, 14, 14, 200)  16200       ['batch_normalization_329[0][0]']
#
#  batch_normalization_330 (Batch  (None, 14, 14, 200)  800        ['conv2d_222[0][0]']
#  Normalization)
#
#  tf.nn.relu6_128 (TFOpLambda)   (None, 14, 14, 200)  0           ['batch_normalization_330[0][0]']
#
#  tf.math.multiply_68 (TFOpLambd  (None, 14, 14, 200)  0          ['batch_normalization_330[0][0]',
#  a)                                                               'tf.nn.relu6_128[0][0]']
#
#  tf.math.truediv_68 (TFOpLambda  (None, 14, 14, 200)  0          ['tf.math.multiply_68[0][0]']
#  )
#
#  depthwise_conv2d_103 (Depthwis  (None, 14, 14, 200)  2000       ['tf.math.truediv_68[0][0]']
#  eConv2D)
#
#  batch_normalization_331 (Batch  (None, 14, 14, 200)  800        ['depthwise_conv2d_103[0][0]']
#  Normalization)
#
#  tf.nn.relu6_129 (TFOpLambda)   (None, 14, 14, 200)  0           ['batch_normalization_331[0][0]']
#
#  tf.math.multiply_69 (TFOpLambd  (None, 14, 14, 200)  0          ['batch_normalization_331[0][0]',
#  a)                                                               'tf.nn.relu6_129[0][0]']
#
#  tf.math.truediv_69 (TFOpLambda  (None, 14, 14, 200)  0          ['tf.math.multiply_69[0][0]']
#  )
#
#  conv2d_223 (Conv2D)            (None, 14, 14, 80)   16080       ['tf.math.truediv_69[0][0]']
#
#  batch_normalization_332 (Batch  (None, 14, 14, 80)  320         ['conv2d_223[0][0]']
#  Normalization)
#
#  add_68 (Add)                   (None, 14, 14, 80)   0           ['batch_normalization_329[0][0]',
#                                                                   'batch_normalization_332[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 14, 14, 184)  14904       ['add_68[0][0]']
#
#  batch_normalization_333 (Batch  (None, 14, 14, 184)  736        ['conv2d_224[0][0]']
#  Normalization)
#
#  tf.nn.relu6_130 (TFOpLambda)   (None, 14, 14, 184)  0           ['batch_normalization_333[0][0]']
#
#  tf.math.multiply_70 (TFOpLambd  (None, 14, 14, 184)  0          ['batch_normalization_333[0][0]',
#  a)                                                               'tf.nn.relu6_130[0][0]']
#
#  tf.math.truediv_70 (TFOpLambda  (None, 14, 14, 184)  0          ['tf.math.multiply_70[0][0]']
#  )
#
#  depthwise_conv2d_104 (Depthwis  (None, 14, 14, 184)  1840       ['tf.math.truediv_70[0][0]']
#  eConv2D)
#
#  batch_normalization_334 (Batch  (None, 14, 14, 184)  736        ['depthwise_conv2d_104[0][0]']
#  Normalization)
#
#  tf.nn.relu6_131 (TFOpLambda)   (None, 14, 14, 184)  0           ['batch_normalization_334[0][0]']
#
#  tf.math.multiply_71 (TFOpLambd  (None, 14, 14, 184)  0          ['batch_normalization_334[0][0]',
#  a)                                                               'tf.nn.relu6_131[0][0]']
#
#  tf.math.truediv_71 (TFOpLambda  (None, 14, 14, 184)  0          ['tf.math.multiply_71[0][0]']
#  )
#
#  conv2d_225 (Conv2D)            (None, 14, 14, 80)   14800       ['tf.math.truediv_71[0][0]']
#
#  batch_normalization_335 (Batch  (None, 14, 14, 80)  320         ['conv2d_225[0][0]']
#  Normalization)
#
#  add_69 (Add)                   (None, 14, 14, 80)   0           ['add_68[0][0]',
#                                                                   'batch_normalization_335[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 14, 14, 184)  14904       ['add_69[0][0]']
#
#  batch_normalization_336 (Batch  (None, 14, 14, 184)  736        ['conv2d_226[0][0]']
#  Normalization)
#
#  tf.nn.relu6_132 (TFOpLambda)   (None, 14, 14, 184)  0           ['batch_normalization_336[0][0]']
#
#  tf.math.multiply_72 (TFOpLambd  (None, 14, 14, 184)  0          ['batch_normalization_336[0][0]',
#  a)                                                               'tf.nn.relu6_132[0][0]']
#
#  tf.math.truediv_72 (TFOpLambda  (None, 14, 14, 184)  0          ['tf.math.multiply_72[0][0]']
#  )
#
#  depthwise_conv2d_105 (Depthwis  (None, 14, 14, 184)  1840       ['tf.math.truediv_72[0][0]']
#  eConv2D)
#
#  batch_normalization_337 (Batch  (None, 14, 14, 184)  736        ['depthwise_conv2d_105[0][0]']
#  Normalization)
#
#  tf.nn.relu6_133 (TFOpLambda)   (None, 14, 14, 184)  0           ['batch_normalization_337[0][0]']
#
#  tf.math.multiply_73 (TFOpLambd  (None, 14, 14, 184)  0          ['batch_normalization_337[0][0]',
#  a)                                                               'tf.nn.relu6_133[0][0]']
#
#  tf.math.truediv_73 (TFOpLambda  (None, 14, 14, 184)  0          ['tf.math.multiply_73[0][0]']
#  )
#
#  conv2d_227 (Conv2D)            (None, 14, 14, 80)   14800       ['tf.math.truediv_73[0][0]']
#
#  batch_normalization_338 (Batch  (None, 14, 14, 80)  320         ['conv2d_227[0][0]']
#  Normalization)
#
#  add_70 (Add)                   (None, 14, 14, 80)   0           ['add_69[0][0]',
#                                                                   'batch_normalization_338[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 14, 14, 480)  38880       ['add_70[0][0]']
#
#  batch_normalization_339 (Batch  (None, 14, 14, 480)  1920       ['conv2d_228[0][0]']
#  Normalization)
#
#  tf.nn.relu6_134 (TFOpLambda)   (None, 14, 14, 480)  0           ['batch_normalization_339[0][0]']
#
#  tf.math.multiply_74 (TFOpLambd  (None, 14, 14, 480)  0          ['batch_normalization_339[0][0]',
#  a)                                                               'tf.nn.relu6_134[0][0]']
#
#  tf.math.truediv_74 (TFOpLambda  (None, 14, 14, 480)  0          ['tf.math.multiply_74[0][0]']
#  )
#
#  depthwise_conv2d_106 (Depthwis  (None, 14, 14, 480)  4800       ['tf.math.truediv_74[0][0]']
#  eConv2D)
#
#  batch_normalization_340 (Batch  (None, 14, 14, 480)  1920       ['depthwise_conv2d_106[0][0]']
#  Normalization)
#
#  tf.nn.relu6_135 (TFOpLambda)   (None, 14, 14, 480)  0           ['batch_normalization_340[0][0]']
#
#  tf.math.multiply_75 (TFOpLambd  (None, 14, 14, 480)  0          ['batch_normalization_340[0][0]',
#  a)                                                               'tf.nn.relu6_135[0][0]']
#
#  tf.math.truediv_75 (TFOpLambda  (None, 14, 14, 480)  0          ['tf.math.multiply_75[0][0]']
#  )
#
#  global_average_pooling2d_56 (G  (None, 480)         0           ['tf.math.truediv_75[0][0]']
#  lobalAveragePooling2D)
#
#  dense_115 (Dense)              (None, 30)           14430       ['global_average_pooling2d_56[0][
#                                                                  0]']
#
#  dense_116 (Dense)              (None, 480)          14880       ['dense_115[0][0]']
#
#  multiply_51 (Multiply)         (None, 14, 14, 480)  0           ['tf.math.truediv_75[0][0]',
#                                                                   'dense_116[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 14, 14, 112)  53872       ['multiply_51[0][0]']
#
#  batch_normalization_341 (Batch  (None, 14, 14, 112)  448        ['conv2d_229[0][0]']
#  Normalization)
#
#  conv2d_230 (Conv2D)            (None, 14, 14, 672)  75936       ['batch_normalization_341[0][0]']
#
#  batch_normalization_342 (Batch  (None, 14, 14, 672)  2688       ['conv2d_230[0][0]']
#  Normalization)
#
#  tf.nn.relu6_136 (TFOpLambda)   (None, 14, 14, 672)  0           ['batch_normalization_342[0][0]']
#
#  tf.math.multiply_76 (TFOpLambd  (None, 14, 14, 672)  0          ['batch_normalization_342[0][0]',
#  a)                                                               'tf.nn.relu6_136[0][0]']
#
#  tf.math.truediv_76 (TFOpLambda  (None, 14, 14, 672)  0          ['tf.math.multiply_76[0][0]']
#  )
#
#  depthwise_conv2d_107 (Depthwis  (None, 14, 14, 672)  6720       ['tf.math.truediv_76[0][0]']
#  eConv2D)
#
#  batch_normalization_343 (Batch  (None, 14, 14, 672)  2688       ['depthwise_conv2d_107[0][0]']
#  Normalization)
#
#  tf.nn.relu6_137 (TFOpLambda)   (None, 14, 14, 672)  0           ['batch_normalization_343[0][0]']
#
#  tf.math.multiply_77 (TFOpLambd  (None, 14, 14, 672)  0          ['batch_normalization_343[0][0]',
#  a)                                                               'tf.nn.relu6_137[0][0]']
#
#  tf.math.truediv_77 (TFOpLambda  (None, 14, 14, 672)  0          ['tf.math.multiply_77[0][0]']
#  )
#
#  global_average_pooling2d_57 (G  (None, 672)         0           ['tf.math.truediv_77[0][0]']
#  lobalAveragePooling2D)
#
#  dense_117 (Dense)              (None, 42)           28266       ['global_average_pooling2d_57[0][
#                                                                  0]']
#
#  dense_118 (Dense)              (None, 672)          28896       ['dense_117[0][0]']
#
#  multiply_52 (Multiply)         (None, 14, 14, 672)  0           ['tf.math.truediv_77[0][0]',
#                                                                   'dense_118[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 14, 14, 112)  75376       ['multiply_52[0][0]']
#
#  batch_normalization_344 (Batch  (None, 14, 14, 112)  448        ['conv2d_231[0][0]']
#  Normalization)
#
#  add_71 (Add)                   (None, 14, 14, 112)  0           ['batch_normalization_341[0][0]',
#                                                                   'batch_normalization_344[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 14, 14, 672)  75936       ['add_71[0][0]']
#
#  batch_normalization_345 (Batch  (None, 14, 14, 672)  2688       ['conv2d_232[0][0]']
#  Normalization)
#
#  tf.nn.relu6_138 (TFOpLambda)   (None, 14, 14, 672)  0           ['batch_normalization_345[0][0]']
#
#  tf.math.multiply_78 (TFOpLambd  (None, 14, 14, 672)  0          ['batch_normalization_345[0][0]',
#  a)                                                               'tf.nn.relu6_138[0][0]']
#
#  tf.math.truediv_78 (TFOpLambda  (None, 14, 14, 672)  0          ['tf.math.multiply_78[0][0]']
#  )
#
#  depthwise_conv2d_108 (Depthwis  (None, 7, 7, 672)   17472       ['tf.math.truediv_78[0][0]']
#  eConv2D)
#
#  batch_normalization_346 (Batch  (None, 7, 7, 672)   2688        ['depthwise_conv2d_108[0][0]']
#  Normalization)
#
#  tf.nn.relu6_139 (TFOpLambda)   (None, 7, 7, 672)    0           ['batch_normalization_346[0][0]']
#
#  tf.math.multiply_79 (TFOpLambd  (None, 7, 7, 672)   0           ['batch_normalization_346[0][0]',
#  a)                                                               'tf.nn.relu6_139[0][0]']
#
#  tf.math.truediv_79 (TFOpLambda  (None, 7, 7, 672)   0           ['tf.math.multiply_79[0][0]']
#  )
#
#  global_average_pooling2d_58 (G  (None, 672)         0           ['tf.math.truediv_79[0][0]']
#  lobalAveragePooling2D)
#
#  dense_119 (Dense)              (None, 42)           28266       ['global_average_pooling2d_58[0][
#                                                                  0]']
#
#  dense_120 (Dense)              (None, 672)          28896       ['dense_119[0][0]']
#
#  multiply_53 (Multiply)         (None, 7, 7, 672)    0           ['tf.math.truediv_79[0][0]',
#                                                                   'dense_120[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 7, 7, 160)    107680      ['multiply_53[0][0]']
#
#  batch_normalization_347 (Batch  (None, 7, 7, 160)   640         ['conv2d_233[0][0]']
#  Normalization)
#
#  conv2d_234 (Conv2D)            (None, 7, 7, 960)    154560      ['batch_normalization_347[0][0]']
#
#  batch_normalization_348 (Batch  (None, 7, 7, 960)   3840        ['conv2d_234[0][0]']
#  Normalization)
#
#  tf.nn.relu6_140 (TFOpLambda)   (None, 7, 7, 960)    0           ['batch_normalization_348[0][0]']
#
#  tf.math.multiply_80 (TFOpLambd  (None, 7, 7, 960)   0           ['batch_normalization_348[0][0]',
#  a)                                                               'tf.nn.relu6_140[0][0]']
#
#  tf.math.truediv_80 (TFOpLambda  (None, 7, 7, 960)   0           ['tf.math.multiply_80[0][0]']
#  )
#
#  depthwise_conv2d_109 (Depthwis  (None, 7, 7, 960)   24960       ['tf.math.truediv_80[0][0]']
#  eConv2D)
#
#  batch_normalization_349 (Batch  (None, 7, 7, 960)   3840        ['depthwise_conv2d_109[0][0]']
#  Normalization)
#
#  tf.nn.relu6_141 (TFOpLambda)   (None, 7, 7, 960)    0           ['batch_normalization_349[0][0]']
#
#  tf.math.multiply_81 (TFOpLambd  (None, 7, 7, 960)   0           ['batch_normalization_349[0][0]',
#  a)                                                               'tf.nn.relu6_141[0][0]']
#
#  tf.math.truediv_81 (TFOpLambda  (None, 7, 7, 960)   0           ['tf.math.multiply_81[0][0]']
#  )
#
#  global_average_pooling2d_59 (G  (None, 960)         0           ['tf.math.truediv_81[0][0]']
#  lobalAveragePooling2D)
#
#  dense_121 (Dense)              (None, 60)           57660       ['global_average_pooling2d_59[0][
#                                                                  0]']
#
#  dense_122 (Dense)              (None, 960)          58560       ['dense_121[0][0]']
#
#  multiply_54 (Multiply)         (None, 7, 7, 960)    0           ['tf.math.truediv_81[0][0]',
#                                                                   'dense_122[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 7, 7, 160)    153760      ['multiply_54[0][0]']
#
#  batch_normalization_350 (Batch  (None, 7, 7, 160)   640         ['conv2d_235[0][0]']
#  Normalization)
#
#  add_72 (Add)                   (None, 7, 7, 160)    0           ['batch_normalization_347[0][0]',
#                                                                   'batch_normalization_350[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 7, 7, 960)    154560      ['add_72[0][0]']
#
#  batch_normalization_351 (Batch  (None, 7, 7, 960)   3840        ['conv2d_236[0][0]']
#  Normalization)
#
#  tf.nn.relu6_142 (TFOpLambda)   (None, 7, 7, 960)    0           ['batch_normalization_351[0][0]']
#
#  tf.math.multiply_82 (TFOpLambd  (None, 7, 7, 960)   0           ['batch_normalization_351[0][0]',
#  a)                                                               'tf.nn.relu6_142[0][0]']
#
#  tf.math.truediv_82 (TFOpLambda  (None, 7, 7, 960)   0           ['tf.math.multiply_82[0][0]']
#  )
#
#  depthwise_conv2d_110 (Depthwis  (None, 7, 7, 960)   24960       ['tf.math.truediv_82[0][0]']
#  eConv2D)
#
#  batch_normalization_352 (Batch  (None, 7, 7, 960)   3840        ['depthwise_conv2d_110[0][0]']
#  Normalization)
#
#  tf.nn.relu6_143 (TFOpLambda)   (None, 7, 7, 960)    0           ['batch_normalization_352[0][0]']
#
#  tf.math.multiply_83 (TFOpLambd  (None, 7, 7, 960)   0           ['batch_normalization_352[0][0]',
#  a)                                                               'tf.nn.relu6_143[0][0]']
#
#  tf.math.truediv_83 (TFOpLambda  (None, 7, 7, 960)   0           ['tf.math.multiply_83[0][0]']
#  )
#
#  global_average_pooling2d_60 (G  (None, 960)         0           ['tf.math.truediv_83[0][0]']
#  lobalAveragePooling2D)
#
#  dense_123 (Dense)              (None, 60)           57660       ['global_average_pooling2d_60[0][
#                                                                  0]']
#
#  dense_124 (Dense)              (None, 960)          58560       ['dense_123[0][0]']
#
#  multiply_55 (Multiply)         (None, 7, 7, 960)    0           ['tf.math.truediv_83[0][0]',
#                                                                   'dense_124[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 7, 7, 160)    153760      ['multiply_55[0][0]']
#
#  batch_normalization_353 (Batch  (None, 7, 7, 160)   640         ['conv2d_237[0][0]']
#  Normalization)
#
#  add_73 (Add)                   (None, 7, 7, 160)    0           ['add_72[0][0]',
#                                                                   'batch_normalization_353[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 7, 7, 960)    154560      ['add_73[0][0]']
#
#  batch_normalization_354 (Batch  (None, 7, 7, 960)   3840        ['conv2d_238[0][0]']
#  Normalization)
#
#  tf.nn.relu6_144 (TFOpLambda)   (None, 7, 7, 960)    0           ['batch_normalization_354[0][0]']
#
#  tf.math.multiply_84 (TFOpLambd  (None, 7, 7, 960)   0           ['batch_normalization_354[0][0]',
#  a)                                                               'tf.nn.relu6_144[0][0]']
#
#  tf.math.truediv_84 (TFOpLambda  (None, 7, 7, 960)   0           ['tf.math.multiply_84[0][0]']
#  )
#
#  global_average_pooling2d_61 (G  (None, 960)         0           ['tf.math.truediv_84[0][0]']
#  lobalAveragePooling2D)
#
#  dense_125 (Dense)              (None, 1280)         1230080     ['global_average_pooling2d_61[0][
#                                                                  0]']
#
#  batch_normalization_355 (Batch  (None, 1280)        5120        ['dense_125[0][0]']
#  Normalization)
#
#  tf.nn.relu6_145 (TFOpLambda)   (None, 1280)         0           ['batch_normalization_355[0][0]']
#
#  tf.math.multiply_85 (TFOpLambd  (None, 1280)        0           ['batch_normalization_355[0][0]',
#  a)                                                               'tf.nn.relu6_145[0][0]']
#
#  tf.math.truediv_85 (TFOpLambda  (None, 1280)        0           ['tf.math.multiply_85[0][0]']
#  )
#
#  dense_126 (Dense)              (None, 10)           12810       ['tf.math.truediv_85[0][0]']
#
# ==================================================================================================
# Total params: 3,124,958
# Trainable params: 3,097,966
# Non-trainable params: 26,992
# __________________________________________________________________________________________________
